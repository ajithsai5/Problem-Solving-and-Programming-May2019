# %% [markdown]
# # PROBLEM SOLVING and PROGRAMMING
# ### Day NO:-
# ### Date -

# %% [markdown]
# ## Day Objectives
# 1. Objectives 1
# 2. Objectives 2
# 3. Objectives 3

# %% [markdown]
# ## Problem 1:-
#
# #### Problem Staments
#  Using the Matplotlib library, generate a Pie Chart to categorise student marks data in a CSV file into Distinction, First Class, Second Class, Third Class and Failed Categories(based on percentages). Explode the Distinction category.
#
#
# #### Test Cases:-
# * Generate a CSV containing marks of 2000 students
# * From the CSV, generate the Pie Chart

# %%
import pandas as pd
import random
def marksdata(filename,ro,n):
    for i in range (0,n):
        rd=random.randint(0,100)
        df=pd.read_csv(filename)
        ro=ro+1
        df.loc[n]=ro,rd
        df.to_csv(filename,index=False)
    return df
marksdata('FileData/marks.csv',221710310000,2000)
df=marksdata('FileData/marks.csv',221710310000,2000)

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
k=df.values
roll=[]
mark=[]
a=[]
b=[]
c=[]
f=[]
for i in range (0,len(k)):
    x=df.values[i][0]
    roll.append(x)
for i in range (0,len(k)):
    y=df.values[i][1]
    mark.append(y)
for i in range(0,len(mark)):
    if (mark[i]>90):
        x=df.values[i]
        a.append(x)
    elif mark[i]>80 and mark[i]<90:
        x=df.values[i]
        b.append(x)
    elif mark[i]>70 and mark[i]<80:
        x=df.values[i]
        c.append(x)  
    elif mark[i]>0 and mark[i]<40:
        x=df.values[i]
        f.append(x)

# %%
labels=['Grade A','Grade B','Grade C','Grade F']
sizes=[len(a),len(b),len(c),len(f)]  
explode=(0.1,0,0,0)

fidl,axl=plt.subplots()
axl.pie(sizes,explode=explode,labels=labels,shadow=True,startangle=90)
axl.axis('equal')
plt.show()

# %%
w=1/5
marks=[len(a),len(b),len(c),len(f)]
roll=['A','B','C','F']
plt.bar(roll,marks,w)
plt.xlabel('Numbers of students')
plt.ylabel('Grades')
plt.title('Total')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Problem 2:-
#
# #### Problem Staments
# Data Visualization of Line Plots

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
plt.plot([1,6,2,3.5,5,1], [35,35,0,55,0,35])
plt.xlabel('time')
plt.ylabel('distance')
plt.show()

# %% [markdown]
# ## Problem 3:-
#
# #### Problem Staments
# Data Visualization of Line Plots using grind

# %%
import numpy as np

s=np.arange(0.0,2.0,0.1)
g=np.sin(2*np.pi*s)

plt.plot(s,g)
plt.grid()

# %% [markdown]
# ## Problem 3:-
#
# #### Problem Staments
# Show the graph of the income of Arkansas

# %%
import pandas as pd
def reasCSV(filename):
    df=pd.read_csv(filename)
    return df
reasCSV('FileData/income.csv')
df=reasCSV('FileData/income.csv')

# %%
x=df.values[4]
y=df.columns
years=[]
income=[]
for i in range (2,len(x)):
    years.append(x[i])
for i in range (2,len(y)):
    income.append(y[i])
plt.plot(income,years)
plt.ylabel('Income')
plt.xlabel('Years')
plt.title('Grahp:-A')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Problem 4:-
#
# #### Problem Staments
# Show the Bar graph of the income of Arkansas

# %%
w=1/5
plt.bar(income,years,w)
plt.xlabel('Years')
plt.ylabel('Income')
plt.title('Grahp:-A')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Problem 4:-
#
# #### Problem Stament
# Data Visualization of Scatter Plot

# %%
import random
n=100
x=np.random.rand(n)
y=np.random.rand(n)
colurs=np.random.rand(n)
s=np.random.rand(n)
area=s*s*100
plt.scatter(x,y,s=area,c=colurs,alpha=5)
plt.show()

# %% [markdown]
# ## Problem 5:-
#
# #### Problem Stament
# Data Visualization of Scatter Plot

# %%
labels=['Happy','Sad','Anger','Lazy']
sizes=[42,60,20,70]  
explode=(0.1,0,0.25,0)

fidl,axl=plt.subplots()
axl.pie(sizes,explode=explode,labels=labels,shadow=True,startangle=90)
axl.axis('equal')
plt.show()
